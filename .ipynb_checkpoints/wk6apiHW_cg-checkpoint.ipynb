# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
owm_key = '&APPID=87cc8d43b5a70c9eea094377511c7804'

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lats = []
lngs =[]
lat_lngs=[]
cities = []
columns = ['city', 'country','latitude', 'longitude', 'temp', 'humidty', 'clouds', 'wind']

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))
#lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
# for lat_lng in lat_lngs:
#     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 0

# %%
df = pd.DataFrame(lat_lngs, columns =['lat', 'long'])
newCity = []

for index, row in df:
    try:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
        newCity.append(city)
    except:
        newCity.append('does not exist')
df["city"] =newCity

    
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-c297f99e8797> in <module>()
#       8     except:
#       9         newCity.append('does not exist')
# ---> 10 df["city"] =newCity
#      11
#      12
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
# ...

# %%
weather_data = pd.DataFrame(columns = columns)
weather_data['latitude'] = lats
weather_data['longitude'] = lngs
weather_data['city'] = cities
weather_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-e9cba62a6ea4> in <module>()
#       2 weather_data['latitude'] = lats[0:644]
#       3 weather_data['longitude'] = lngs[0:644]
# ----> 4 weather_data['city'] = cities
#       5 weather_data
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
city_list_dict= pd.DataFrame({'Lat': lats,
                        'Long':lngs,
                            'lat_long':"".join(lats, lngs, ",")})
# city_list = pd.DataFrame.from_dict(city_list_dict, orient='index')
city_list_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-183c5816ece5> in <module>()
#       1 city_list_dict= pd.DataFrame({'Lat': lats,
#       2                         'Long':lngs,
# ----> 3                             'lat_long':"".join(lats, lngs, ",")})
#       4 # city_list = pd.DataFrame.from_dict(city_list_dict, orient='index')
#       5 city_list_dict
#
# TypeError: join() takes exactly one argument (3 given)

# %% [markdown]
# ## Perform API Calls

# %% [markdown]
# Temperature (F)  |  Humidity (%)   |   Cloudiness (%)   |  Wind Speed (mph)

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?q={}{}&units=Imperial".format(city, owm_key).replace(" ", "%20")
data = requests.get(url).json()

# %%
city_loc= pd.DataFrame(city, lats, lngs)
temp = []
humidity = []
clouds = []
wind = []

for city in cities:
    temp.append(data['main']['temp'])
    humidity.append(data['main']['humidity'])
    clouds.append(data['clouds']['all'])
    wind.append(data['wind']['speed'])
# Out:
# [5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
#  5.82,
# ...

# %%
#storing the data collected
weather_data = pd.DataFrame({'city': city,
                'Temperature': temp,
                'Humidity': humidity,
                'Cloudiness':clouds,
                'Wind Speed': wind,})
city_weather = [['city name', 'temp', 'humidity', 'cloudiness', 'wind']]
city_weather
# Out:
# [['city name', 'temp', 'humidity', 'cloudiness', 'wind']]

# %%
temp = data['main']['temp']
humidity = data['main']['humidity']
clouds = data['clouds']['all']
wind = data['wind']['speed']

# %%
#data frame
weather_df = pd.DataFrame(city_weather, index=city)

weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-f6132113a844> in <module>()
#       1 #data frame
# ----> 2 weather_df = pd.DataFrame(city_weather, index=city)
#       3
#       4 weather_df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# ...

# %%
# Out:
# citipy.citipy.City
